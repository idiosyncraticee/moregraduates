# %%
import pandas as pd
import io
import bz2, urllib2
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
#Dropouts by Race & Gender
url = "http://dq.cde.ca.gov/dataquest/dlfile/dlfile.aspx?cLevel=School&cYear=2012-13&cCat=Dropouts&cPage=filesdropouts"
raw_data = urllib2.urlopen(url).read()
df_dropouts_by_race_gender = pd.read_csv(io.BytesIO(raw_data),sep='\t')
df_dropouts_by_race_gender.head(1)

# %%
#Dropouts by Race & Gender
url = "http://dq.cde.ca.gov/dataquest/dlfile/dlfile.aspx?cLevel=All&cYear=0910&cCat=NcesRate&cPage=filesncesrate"
raw_data = urllib2.urlopen(url).read()
df_nces_graduation_rate = pd.read_csv(io.BytesIO(raw_data),sep='\t')
df_nces_graduation_rate.head(1)

# %%
# Out:
#         CDS_CODE  ETHNIC GENDER  E7  E8  E9  E10  E11  E12  EUS  ETOT  D7  D8  \
# 0  1100170109835       0      M   0   0   1    0    2    1    0     4   0   0
# 1  1100170109835       0      F   1   0   0    2    1    0    0     3   0   0
# 2  1100170109835       1      M   1   0   1    0    0    0    0     1   0   0
# 3  1100170109835       1      F   2   1   0    0    0    1    0     1   0   0
# 4  1100170109835       2      M  15  12   4   10    9    3    0    26   0   0
# 5  1100170109835       2      F  13   6   9    9    7    7    0    32   0   0
# 6  1100170109835       3      M   1   0   0    0    1    1    0     2   0   0
# 7  1100170109835       3      F   0   0   0    1    1    1    0     3   0   0
# 8  1100170109835       4      M   0   1   1    0    1    0    0     2   0   0
# 9  1100170109835       4      F   1   2   0    0    1    0    0     1   0   0
#
#    D9_x  D10_x  D11_x  D12_x  DUS  DTOT  YEAR_x
# 0     0      0      0      0    0     0    1213 ...
# ...

# %% [markdown]
# <table width="95%" border="1" cellpadding="2" cellspacing="0">
#   <tr>
#     <th>Field Name </th>
#     <th>Type Field </th>
#     <th>Width </th>
#     <th align="left">Description </th>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>CDS_CODE </strong></td>
#     <td valign="top">Character </td>
#     <td valign="top">14 </td>
#     <td valign="top">This 14-digit code is the official, unique identification of a school within California. The first two digits identify the county, the next five digits identify the school district, and the last seven digits identify the school. </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>ETHNIC</strong></td>
#     <td valign="top">Character </td>
#     <td valign="top">1 </td>
#     <td valign="top">This is a coded field for racial/ethnic designation. The racial/ethnic designations are coded as follows:&nbsp;
#       <ul>
#         <li> Code 0 = Not reported</li>
#         <li> Code 1 = American Indian or Alaska Native, Not Hispanic</li>
#         <li> Code 2 = Asian, Not Hispanic</li>
#         <li> Code 3 = Pacific Islander, Not Hispanic</li>
#         <li> Code 4 = Filipino, Not Hispanic</li>
#         <li> Code 5 = Hispanic or Latino</li>
#         <li> Code 6 = African American, not Hispanic (formerly known as Black, not Hispanic)</li>
#         <li> Code 7 = White, not Hispanic</li>
#         <li> Code 9 = Two or More Races, Not Hispanic</li>
#       </ul>
#       <p>(See <a href="../cb/glossary.asp">Glossary</a> for complete definitions of the ethnic groups.)                    <br>
#     </p></td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>GENDER</strong></td>
#     <td valign="top">Character </td>
#     <td valign="top">1</td>
#     <td><p>This field is a coded field identifying gender. The gender is coded as follows: </p>
#       <ul>
#         <li>M = Male
#         <li>F = Female </li>
#     </ul></td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>E7 </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">5 </td>
#     <td>Enrollment in grade seven. (Not included in enrollment total (ETOT) field below). </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>E8 </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">5 </td>
#     <td>Enrollment in grade eight. (Not included in enrollment total (ETOT) field below) . </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>E9 </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">5 </td>
#     <td>Enrollment in grade nine. </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>E10 </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">5 </td>
#     <td>Enrollment in grade ten. </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>E11 </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">5 </td>
#     <td>Enrollment in grade eleven. </td>
#   </tr>
#   <tr>
#     <td align="left"><strong>E12 </strong></td>
#     <td>Numeric </td>
#     <td>5 </td>
#     <td>Enrollment in grade twelve. </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>EUS </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">5 </td>
#     <td>Enrollment in ungraded secondary classes. </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>ETOT </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">6 </td>
#     <td>Total enrollment for grades nine through twelve and ungraded secondary.
#     (Does not include grades seven and eight). </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>D7 </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">4 </td>
#     <td>Dropouts in grade seven. (Not included in dropout total (DTOT) field below) </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>D8 </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">4 </td>
#     <td>Dropouts in grade eight. (Not included in dropout total (DTOT) field below) . </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>D9 </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">4 </td>
#     <td>Dropouts in grade nine. </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>D10 </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">4 </td>
#     <td>Dropouts in grade ten. </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>D11 </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">4 </td>
#     <td>Dropouts in grade eleven. </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>D12 </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">4 </td>
#     <td>Dropouts in grade twelve. </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>DUS</strong></td>
#     <td valign="top">Numeric</td>
#     <td valign="top">4</td>
#     <td>Dropouts in ungraded secondary classes.</td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>DTOT </strong></td>
#     <td valign="top">Numeric </td>
#     <td valign="top">5 </td>
#     <td>Total dropouts for grades nine through twelve and ungraded secondary.
#     (Does not include grades seven and eight). </td>
#   </tr>
#   <tr>
#     <td valign="top" align="left"><strong>YEAR </strong></td>
#     <td valign="top">Character </td>
#     <td valign="top">5 </td>
#     <td valign="top">Year of data. </td>
#   </tr>
# </table>

# %%
df_dropouts_by_race_gender.head(20)
# Out:
#          CDS_CODE  ETHNIC GENDER  E7  E8  E9  E10  E11  E12  EUS  ETOT  D7  \
# 0   1100170109835       0      M   0   0   1    0    2    1    0     4   0
# 1   1100170109835       0      F   1   0   0    2    1    0    0     3   0
# 2   1100170109835       1      M   1   0   1    0    0    0    0     1   0
# 3   1100170109835       1      F   2   1   0    0    0    1    0     1   0
# 4   1100170109835       2      M  15  12   4   10    9    3    0    26   0
# 5   1100170109835       2      F  13   6   9    9    7    7    0    32   0
# 6   1100170109835       3      M   1   0   0    0    1    1    0     2   0
# 7   1100170109835       3      F   0   0   0    1    1    1    0     3   0
# 8   1100170109835       4      M   0   1   1    0    1    0    0     2   0
# 9   1100170109835       4      F   1   2   0    0    1    0    0     1   0
# 10  1100170109835       5      M   5   6   1    2    5    7    0    15   0
# ...

# %% [raw]
# Only consider schools that have enrolled students in grades 9-12

# %%
#df_dropouts_by_school = df_dropouts_by_race_gender.sum('CDS_CODE')
df_dropouts_by_school = df_merge_df_dropouts_by_race_gender_school_info.groupby(['CDS_CODE']).sum()
#df_dropouts_by_school.head()

#RESET THE INDEX AFTER THE GROUPBY
df_dropouts_by_school.reset_index(level=0, inplace=True)


#HAVE TO DO THE MERGE AFTER THE SUM
df_merge_df_dropouts_by_school_info = pd.merge(df_dropouts_by_school,df_nces_graduation_rate,on='CDS_CODE')
df_merge_df_dropouts_by_school_info.head(10)
# Out:
# 0                               FAME Public Charter
# 1            Envision Academy for Arts & Technology
# 2     Aspire California College Preparatory Academy
# 3                Alameda County Juvenile Hall/Court
# 4                          Alameda County Community
# 5                        Alameda County Opportunity
# 6                   California School for the Blind
# 7            California School for the Deaf-Fremont
# 8                           Nonpublic, nonsectarian
# 9          Alameda Science and Technology Institute
# 10                    Nea Community Learning Center
# 11                                     Alameda High
# 12                Alameda Community Learning Center
# 13                    Bay Area School of Enterprise
# 14                                     Encinal High
# ...
# 4883                       Camptonville Elementary
# 4884                          Camptonville Academy
# 4885    Yuba Environmental Science Charter Academy
# ...

# %%
df_merge_df_dropouts_by_school_info = df_merge_df_dropouts_by_school_info[df_merge_df_dropouts_by_school_info['ETOT'] > 0]

# %%
df_merge_df_dropouts_by_school_info['PD']=df_merge_df_dropouts_by_school_info['DTOT']/df_merge_df_dropouts_by_school_info['ETOT']

# %%
sorted_df_merge_df_dropouts_by_school_info = df_merge_df_dropouts_by_school_info.sort_index(by='ETOT', ascending=False)

# %%
sorted_df_merge_df_dropouts_by_school_info['PD'].head()
# Out:
# 1683    0.026073
# 1242    0.029564
# 1115    0.008310
# 1473    0.010180
# 1244    0.018009
# Name: PD, dtype: float64

# %%
sorted_df_merge_df_dropouts_by_school_info.shape
# Out:
# (2760, 37)

# %%
df_big_schools = sorted_df_merge_df_dropouts_by_school_info[:100]
df_big_schools.head(20)
# Out:
#             CDS_CODE  ETHNIC  E7   E8    E9   E10   E11   E12  EUS  ETOT  D7  \
# 1683  19648731936749      73   1    2  1282  1285  1221  1198    0  4986   0
# 1242  19647251936947      74   0    0  1184  1190  1098  1162    0  4634   0
# 1115  19644511932441      74   0    0  1110  1154  1118   939   11  4332   0
# 1473  19647331933746      74   0    0  1069  1071  1035  1049    0  4224   0
# 1244  19647251939875      74   0    0  1083  1042  1124   860    0  4109   0
# 585   10739651030626      74   0    0  1126  1007  1014   860   15  4022   0
# 1241  19647251935758      74   0    0  1044  1021   990   954    0  4009   0
# 84     1612420134668      73   0    0  1003  1022   962   947    0  3934   0
# 1240  19647251934678      74   0    0   973  1016   936   906    0  3831   0
# 2254  30103063030764      74  48  132   653   779  1266  1105    0  3803   3
# 1460  19647331932623      74   0    0  1007   953   909   897    0  3766   0
# ...

# %%
fig = plt.figure()
ax = df_big_schools['DTOT'].plot(kind='bar', use_index=True)

ax2 = ax.twinx()
ax2.plot(ax.get_xticks(),df_big_schools['ETOT'], linestyle='-', marker='o', linewidth=2.0)

# %%
#df_big_schools.sort_index(by='PD', ascending=False).ix[:,['SCHOOL', 'ETOT','DTOT','PD']]
df_big_schools.rename(columns={'PD': 'Percentage Dropouts'}, inplace=True)
df_big_schools
# Out:
#             CDS_CODE  ETHNIC  E7   E8    E9   E10   E11   E12  EUS  ETOT  D7  \
# 1683  19648731936749      73   1    2  1282  1285  1221  1198    0  4986   0
# 1242  19647251936947      74   0    0  1184  1190  1098  1162    0  4634   0
# 1115  19644511932441      74   0    0  1110  1154  1118   939   11  4332   0
# 1473  19647331933746      74   0    0  1069  1071  1035  1049    0  4224   0
# 1244  19647251939875      74   0    0  1083  1042  1124   860    0  4109   0
# 585   10739651030626      74   0    0  1126  1007  1014   860   15  4022   0
# 1241  19647251935758      74   0    0  1044  1021   990   954    0  4009   0
# 84     1612420134668      73   0    0  1003  1022   962   947    0  3934   0
# 1240  19647251934678      74   0    0   973  1016   936   906    0  3831   0
# 2254  30103063030764      74  48  132   653   779  1266  1105    0  3803   3
# 1460  19647331932623      74   0    0  1007   953   909   897    0  3766   0
# ...
